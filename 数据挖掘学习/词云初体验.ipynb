# %%
from wordcloud import WordCloud
import jieba

# %%
with open('./text.txt','r') as f:
    text = f.read()

# %%
text_gen = jieba.cut(text)
text = ' '.join(text_gen)

# %%
w = WordCloud(font_path=r'C:\Fonts\simhei.ttf',background_color='white',width=1920,height=1080)

# %%
w.generate(text)

# %%
w.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x28D16A1C048>

# %%
w.to_file('wordcloud.png')
