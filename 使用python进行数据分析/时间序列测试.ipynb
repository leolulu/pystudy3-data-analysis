# %%
import pandas as pd 
import numpy as np
from datetime import datetime
from dateutil.parser import parse

# %%
date_range=pd.date_range(start='2018-09-01 00:00:00',freq='S',periods=10000000)

# %%
a1 = pd.DataFrame(
    np.random.randint(1,100,size=(10000000,4)),
    columns = ['buzzkill','fuck','bonerkill','shit'],
    index=date_range
)

# %%
# Out:
#                      buzzkill  fuck  bonerkill  shit
# 2018-11-13 14:30:00        58    82         66     1
# 2018-11-13 14:30:01        46    34         17    21
# 2018-11-13 14:30:02        80    17          7    36
# 2018-11-13 14:30:03        97     8         49    23
# 2018-11-13 14:30:04         9    30         77    78
# 2018-11-13 14:30:05        46    74         70    92
# 2018-11-13 14:30:06        17    53         27    65
# 2018-11-13 14:30:07        58    60         94    50
# 2018-11-13 14:30:08        95    66         67    93
# 2018-11-13 14:30:09        83    64         47    77
# 2018-11-13 14:30:10        33    21         12    36
# 2018-11-13 14:30:11        56    86         67    67
# 2018-11-13 14:30:12        64    15         16    85
# 2018-11-13 14:30:13        40    55         80    92
# 2018-11-13 14:30:14        82    34         77    39
# 2018-11-13 14:30:15        66    97         71    33
# 2018-11-13 14:30:16        13    11         50    34
# ...

# %%
def date_split(x):
    if x
