# %%
import seaborn as sns
import pandas as pd
import missingno as msno
import pyecharts

# %%
data = sns.load_dataset('titanic')

# %%
data.dropna(inplace=True)
data = data[:10]

# %%
data
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 1          1       1  female  38.0      1      0   71.2833        C   First
# 3          1       1  female  35.0      1      0   53.1000        S   First
# 6          0       1    male  54.0      0      0   51.8625        S   First
# 10         1       3  female   4.0      1      1   16.7000        S   Third
# 11         1       1  female  58.0      0      0   26.5500        S   First
# 21         1       2    male  34.0      0      0   13.0000        S  Second
# 23         1       1    male  28.0      0      0   35.5000        S   First
# 27         0       1    male  19.0      3      2  263.0000        S   First
# 52         1       1  female  49.0      1      0   76.7292        C   First
# 54         0       1    male  65.0      0      1   61.9792        C   First
#
#       who  adult_male deck  embark_town alive  alone
# 1   woman       False    C    Cherbourg   yes  False
# ...

# %%
bar = pyecharts.Bar('泰坦立刻')
bar.add('pclass',data.index,data.pclass)
bar.add('survived',data.index,data.survived)
bar.add('fare',data.index,data.fare)
bar.add('age',data.index,data.age)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ace695160bfc481c8a6af05c1a5306ed" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ace695160bfc481c8a6af05c1a5306ed = echarts.init(document.getElementById('ace695160bfc481c8a6af05c1a5306ed'), 'light', {renderer: 'canvas'});
#
# var option_ace695160bfc481c8a6af05c1a5306ed = {
#     "title": [
#         {
#             "text": "\u6cf0\u5766\u7acb\u523b",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
# ...

# %%
sns.barplot(data=data2,y='value',hue='variable',x='index')

# %%
data2 = data.reset_index(0)
data2
# Out:
#    index  survived  pclass     sex   age  sibsp  parch      fare embarked  \
# 0      1         1       1  female  38.0      1      0   71.2833        C
# 1      3         1       1  female  35.0      1      0   53.1000        S
# 2      6         0       1    male  54.0      0      0   51.8625        S
# 3     10         1       3  female   4.0      1      1   16.7000        S
# 4     11         1       1  female  58.0      0      0   26.5500        S
# 5     21         1       2    male  34.0      0      0   13.0000        S
# 6     23         1       1    male  28.0      0      0   35.5000        S
# 7     27         0       1    male  19.0      3      2  263.0000        S
# 8     52         1       1  female  49.0      1      0   76.7292        C
# 9     54         0       1    male  65.0      0      1   61.9792        C
#
#     class    who  adult_male deck  embark_town alive  alone
# 0   First  woman       False    C    Cherbourg   yes  False
# ...

# %%
data2 = pd.melt(data2,id_vars=['index'],value_vars=['pclass','survived','fare','age'])

# %%
data2
# Out:
#     index  variable     value
# 0       1    pclass    1.0000
# 1       3    pclass    1.0000
# 2       6    pclass    1.0000
# 3      10    pclass    3.0000
# 4      11    pclass    1.0000
# 5      21    pclass    2.0000
# 6      23    pclass    1.0000
# 7      27    pclass    1.0000
# 8      52    pclass    1.0000
# 9      54    pclass    1.0000
# 10      1  survived    1.0000
# 11      3  survived    1.0000
# 12      6  survived    0.0000
# 13     10  survived    1.0000
# 14     11  survived    1.0000
# 15     21  survived    1.0000
# 16     23  survived    1.0000
# 17     27  survived    0.0000
# 18     52  survived    1.0000
# 19     54  survived    0.0000
# 20      1      fare   71.2833
# 21      3      fare   53.1000
# 22      6      fare   51.8625
# 23     10      fare   16.7000
# 24     11      fare   26.5500
# 25     21      fare   13.0000
# 26     23      fare   35.5000
# 27     27      fare  263.0000
# 28     52      fare   76.7292
# 29     54      fare   61.9792
# ...
