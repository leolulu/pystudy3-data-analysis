# %%
import pandas as pd

# %%
df = pd.read_csv('sankaku数据.csv',engine='python')

# %%
df = df.head()

# %%
df.loc[0,'tag_list']
# Out:
# "['azur lane', 'deutschland (azur lane)', 'ioa2324', 'high resolution', '1girl', 'bangs', 'black hair', 'blue eyes', 'breasts', 'cleavage', 'female', 'gun', 'hair ornament', 'kimono', 'large breasts', 'long hair', 'long sleeves', 'multicolored hair', 'nengajou', 'new year', 'red hair', 'rigging', 'streaked hair', 'thighhighs', 'very long hair', 'wafuku', 'weapon', 'wide sleeves']"

# %%
df2 = df['tag_list'].str.split(',',expand=True)
df2.reset_index(inplace=True)
df2
# Out:
#    index                     0                           1  \
# 0      0          ['azur lane'   'deutschland (azur lane)'
# 1      1  ['super mario bros.'                  'bowsette'
# 2      2  ['ajino (sakanahen)'           'high resolution'
# 3      3      ['fate (series)'          'fate/grand order'
# 4      4    ["luigi's mansion"                   'booette'
#
#                             2                      3                     4  \
# 0                   'ioa2324'      'high resolution'               '1girl'
# 1             'fan character'               'bowser'    '1:1 aspect ratio'
# 2                      '1boy'                '1girl'               'ahoge'
# 3   'abigail williams (fate)'     'akira (aristole)'   'simple background'
# 4                       'boo'   'shuuichi (gothics)'   'simple background'
#
#                      5              6                   7             8  \
# 0              'bangs'   'black hair'         'blue eyes'     'breasts'
# ...

# %%
df2.melt(id_vars='index')
# Out:
#      index variable                       value
# 0        0        0                ['azur lane'
# 1        1        0        ['super mario bros.'
# 2        2        0        ['ajino (sakanahen)'
# 3        3        0            ['fate (series)'
# 4        4        0          ["luigi's mansion"
# 5        0        1   'deutschland (azur lane)'
# 6        1        1                  'bowsette'
# 7        2        1           'high resolution'
# 8        3        1          'fate/grand order'
# 9        4        1                   'booette'
# 10       0        2                   'ioa2324'
# 11       1        2             'fan character'
# 12       2        2                      '1boy'
# 13       3        2   'abigail williams (fate)'
# 14       4        2                       'boo'
# 15       0        3           'high resolution'
# 16       1        3                    'bowser'
# 17       2        3                     '1girl'
# 18       3        3          'akira (aristole)'
# ...
